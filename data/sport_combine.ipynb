# %% [markdown]
# https://www.hopkinsmedicine.org/health/conditions-and-diseases/sports-injuries/sports-injury-statistics
#
# https://ope.ed.gov/athletics/#/
#
# https://data.mendeley.com/datasets/m39ymdv48s/3

# %%
import pandas as pd

# %%
injuries = pd.read_csv("")
