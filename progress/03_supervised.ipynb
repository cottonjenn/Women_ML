# %%
## packages
import pandas as pd 
import numpy as numpy
import statsmodels.api as sm

# %%
## read in data
df2 = pd.read_csv('../data/smaller_qol.csv')
# Out:
# /var/folders/nx/y262pp8d4dzf82b2kl0f_g340000gn/T/ipykernel_40730/2283055885.py:2: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('../data/smaller_qol.csv')

# %%
## drop rows that have missing age, sex, race, degree, educ, religion, marital, happy, life, health
df2 = df2.dropna(subset=['age', 'sex', 'race', 'degree', 'educ', 'relig', 'marital', 'happy', 'life', 'health'])

# %%
## dataset with just age, sex, race, degree, educ, religion, marital, happy, life, health
test_df = df2[['age', 'sex_new', 'race', 'degree', 'educ', 'relig', 'marital', 'happy_new', 'life_new', 'health_new']]

# %%
## count NAs for new df
print(test_df.isnull().sum())
test_df.shape[0]
# Out:
# age           0
# sex_new       0
# race          0
# degree        0
# educ          0
# relig         0
# marital       0
# happy_new     0
# life_new      0
# health_new    0
# dtype: int64
# 43163
